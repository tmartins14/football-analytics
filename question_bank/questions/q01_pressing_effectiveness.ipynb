# %% [markdown]
# # Question 1: Pressing Effectiveness in the Champions League
#
# **Tier 1 — Foundational**
#
# **Question:** Who are the most effective pressers in the Champions League, and does pressure success rate predict defensive outcomes?
#
# **Data:** StatsBomb Open Data — Champions League event data
#
# **Why this question matters:**
# Pressing is one of the most discussed tactics in modern football, but raw press volume tells you little about quality. A player who pressures 10 times and wins the ball 5 times is more valuable defensively than one who pressures 20 times and wins it twice. This question asks you to separate press frequency from press effectiveness — a distinction practitioners care about.
#
# **What you are building toward:**
# By the end of this notebook you should be able to answer:
# - Which players press most frequently?
# - Which players press most *effectively*?
# - Does team-level pressure success rate correlate with defensive outcomes (goals conceded, xG conceded)?
#
# ---
#
# **Critical lens (apply throughout):**
# 1. What does pressure success rate actually measure — and what does it ignore?
# 2. When would a high pressure success rate mislead you about a player's defensive value?
# 3. What confounders might explain the relationship between pressing and defensive outcomes?

# %% [markdown]
# ## Environment Setup
#
# Install and import required libraries.

# %%
# Install required libraries if not already installed
# !pip install statsbombpy mplsoccer pandas numpy matplotlib seaborn

# %%
# Import libraries

# %% [markdown]
# ## Step 1: Explore Available StatsBomb Data
#
# Before loading match data, understand what competitions and seasons are available in the StatsBomb open dataset.
#
# **Hint:** `statsbombpy` has a `sb.competitions()` function that returns a DataFrame of all available competitions and seasons.

# %%
# Load and display available competitions

# %% [markdown]
# ## Step 2: Load Champions League Match Data
#
# Filter to Champions League competitions and load match data for a season of your choice.
#
# **Things to consider:**
# - Which Champions League season has the most matches available?
# - `sb.matches(competition_id, season_id)` returns all matches for a given competition and season
# - Note the `match_id` column — you will need this to load event data

# %%
# Filter to Champions League and load matches for your chosen season

# %% [markdown]
# ## Step 3: Load Event Data
#
# Load event data across all matches in your chosen season.
#
# **Hint:** `sb.events(match_id)` loads events for a single match. You will need to loop across all match IDs and concatenate the results into a single DataFrame.
#
# **Warning:** This will take a few minutes depending on how many matches are available. Print progress as you go.

# %%
# Load all event data for your chosen season
# Loop across match IDs, load events, concatenate into a single DataFrame

# %% [markdown]
# ## Step 4: Explore the Event Data Schema
#
# Before jumping to pressing metrics, understand the shape and structure of the data.
#
# **Questions to answer in this step:**
# - How many rows are in the full dataset?
# - What event types exist?
# - What columns are available?
# - How are pressure events flagged — is there a dedicated event type, a flag on another event, or both?

# %%
# Explore the shape and structure of the event data

# %%
# What event types exist? How many of each?

# %%
# Isolate pressure events specifically
# How is a pressure event defined in the StatsBomb schema?

# %% [markdown]
# ## Step 5: Define Pressure Success
#
# This is the most important analytical decision in the notebook. Before writing any code, answer this in a markdown cell:
#
# **How will you define a successful pressure?**
#
# StatsBomb provides a `counterpress` flag and tracks what happens after a pressure event. Think carefully about what "success" means:
# - Is it a turnover within N seconds?
# - Is it the pressured player making a bad pass?
# - Is it possession regained within N events?
#
# Document your definition and your reasoning before building the metric.

# %% [markdown]
# **My definition of pressure success:**
#
# *(Write your definition here before writing any code)*

# %%
# Build a pressure success flag based on your definition above

# %% [markdown]
# ## Step 6: Player-Level Pressing Metrics
#
# Calculate the following for each player across the season:
# - Total pressures applied
# - Total successful pressures
# - Pressure success rate (successful / total)
# - Pressures per 90 minutes
# - Successful pressures per 90 minutes
#
# **Things to consider:**
# - Set a minimum pressure threshold to exclude players with very small samples
# - Per 90 normalisation requires minutes played — how will you calculate that from event data?
# - What is a reasonable minimum threshold and why?

# %%
# Calculate player-level pressing metrics

# %%
# Apply minimum threshold and display top pressers by success rate

# %% [markdown]
# ## Step 7: Visualise Player Pressing Profiles
#
# Build a scatter plot of pressure volume (x-axis) vs pressure success rate (y-axis).
#
# **What to look for:**
# - Is there a trade-off between volume and success rate?
# - Where do elite pressers sit relative to the rest?
# - Are there players with both high volume and high success rate — and who are they?
#
# **Visualisation standards:**
# - Label the top 10 players by name
# - Add a horizontal line at the median success rate
# - Add a vertical line at the median pressure volume
# - Use quadrant logic to categorise: high volume/high success, high volume/low success, etc.

# %%
# Build pressing profile scatter plot

# %% [markdown]
# ## Step 8: Team-Level Pressing Metrics
#
# Aggregate pressing metrics to the team level:
# - Total pressures per 90
# - Team pressure success rate
# - Pressures in the final third vs own half (where is the press applied?)
#
# **Note:** Pressing location matters significantly. A team pressing high up the pitch has a different risk/reward profile than one pressing in its own half. Separate these.

# %%
# Calculate team-level pressing metrics

# %%
# Separate pressures by pitch zone — final third vs middle third vs own half

# %% [markdown]
# ## Step 9: Does Pressure Success Rate Predict Defensive Outcomes?
#
# This is the core analytical question. Join your team-level pressing metrics to defensive outcome data.
#
# **Defensive outcomes to test against:**
# - Goals conceded per 90
# - xG conceded per 90 (requires shot data from the same dataset)
# - Clean sheet percentage
#
# **Approach:**
# 1. Build a team-level DataFrame with pressing metrics and defensive outcomes
# 2. Produce scatter plots for each relationship
# 3. Calculate correlation coefficients
# 4. Interpret the results critically — correlation is not causation

# %%
# Calculate defensive outcomes per team

# %%
# Join pressing metrics to defensive outcomes

# %%
# Scatter plots: pressing metrics vs defensive outcomes

# %%
# Correlation coefficients

# %% [markdown]
# ## Step 10: Interpret and Critique Your Findings
#
# Answer the following questions in the cells below. These are not code cells — they are analytical judgements.
#
# Write at least two paragraphs per question.

# %% [markdown]
# **10a. Who are the most effective pressers in this Champions League season, and what separates them from high-volume but lower-success pressers?**
#
# *(Write your answer here)*

# %% [markdown]
# **10b. Does pressure success rate predict defensive outcomes? What does your data show, and how strong is the relationship?**
#
# *(Write your answer here)*

# %% [markdown]
# **10c. What are the limitations of your analysis? What would you need to make a stronger causal claim?**
#
# *(Write your answer here)*

# %% [markdown]
# **10d. When would pressure success rate mislead you? Build a specific scenario where a high success rate reflects something other than good pressing.**
#
# *(Write your answer here)*

# %% [markdown]
# ## Extension: Pressing Pitch Map
#
# Using `mplsoccer`, build a pitch map showing where pressures are applied for the top three pressing teams in your dataset.
#
# **What to look for:** Do high-success pressing teams press in different locations to high-volume but lower-success teams?

# %%
# Build pressing pitch maps for top 3 pressing teams using mplsoccer

# %% [markdown]
# ---
#
# ## Before You Move to Question 2
#
# Answer these questions honestly:
#
# 1. Could you explain your pressing success definition to a coaching staff and defend it?
# 2. Did your findings surprise you? If not, ask whether you built the analysis to confirm what you already believed.
# 3. What is the one thing this analysis cannot tell you that you wish it could?
#
# Add your answers to `CANDIDATE_PROBLEMS.md` if any new questions surfaced during this work.

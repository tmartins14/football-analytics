# %% [markdown]
# # Question 25: Systematic xG vs Actual Goals Differences Across Big 5 Leagues
#
# **Tier 5 — System Level**
#
# **Question:** Which leagues show the greatest systematic difference between xG and actual goals at the team level over multiple seasons — and what structural factors explain it?
#
# **Data:** Understat — all Big 5 leagues multi-season + FBref
#
# **Why this question matters:**
# xG models are typically trained on mixed-league data. If a specific league systematically over or underconverts relative to xG, the model is miscalibrated for that league. Understanding which leagues deviate most — and why — has implications for how analysts should apply xG models cross-league and what structural factors (referee interpretation, defensive style, goalkeeper quality distribution) explain the deviation.
#
# **What you are building toward:**
# - Multi-season xG vs actual goals comparison across all Big 5 leagues
# - Statistical test for systematic deviation by league
# - Hypothesis testing for structural explanations
#
# ---
#
# **Critical lens (apply throughout):**
# 1. What would cause a league to systematically over or underconvert relative to an xG model trained on pooled data?
# 2. Is systematic deviation evidence of model miscalibration or genuine structural differences in how football is played?
# 3. How many seasons of data do you need to distinguish systematic deviation from random variance?

# %% [markdown]
# ## Environment Setup

# %%
# !pip install statsbombpy mplsoccer pandas numpy matplotlib seaborn

# %%
# Import libraries

# %% [markdown]
# ## Step 1: Load multi-season xG and goals data from Understat
#
# Pull team-level xG and actual goals for all Big 5 leagues across 5+ seasons.

# %% [markdown]
# ## Step 2: Calculate deviation metric
#
# For each team-season: actual goals minus xG (absolute and per shot). Aggregate to league-season level.

# %% [markdown]
# ## Step 3: Statistical test for systematic deviation
#
# For each league: t-test of whether mean deviation is significantly different from zero across seasons.

# %% [markdown]
# ## Step 4: Cross-league comparison
#
# Which league shows the most consistent systematic deviation? Is it stable across seasons or does it shift?

# %% [markdown]
# ## Step 5: Hypothesis testing for explanations
#
# Test candidate explanations: goalkeeper quality distribution, referee foul interpretation, defensive style compactness. Pull relevant metrics from FBref.

# %% [markdown]
# ## Step 6: Model recalibration discussion
#
# How would you adjust an xG model for league-specific use — and what are the costs of doing so?

# %% [markdown]
# ## Interpretation and Critique

# %% [markdown]
# **1. Which league shows the most systematic deviation from xG predictions — and is it statistically significant?**
#
# *(Write your answer here)*

# %% [markdown]
# **2. What structural factors best explain the deviation you found — and how did you test each hypothesis?**
#
# *(Write your answer here)*

# %% [markdown]
# **3. How should analysts adjust when applying an xG model trained on Premier League data to evaluate Serie A players?**
#
# *(Write your answer here)*

# %% [markdown]
# **4. What does this analysis tell you about the limits of universal football metrics?**
#
# *(Write your answer here)*

# %% [markdown]
# ---
#
# ## Before You Move On
#
# 1. Does your analysis pass the smell test — do the results make intuitive football sense?
# 2. What is the single biggest limitation of your methodology?
# 3. What new question did this analysis raise that it cannot answer?
#
# Add new questions to `CANDIDATE_PROBLEMS.md` before moving on.

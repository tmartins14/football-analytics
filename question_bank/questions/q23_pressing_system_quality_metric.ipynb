# %% [markdown]
# # Question 23: Pressing System Quality Metric Separating Tactics from Personnel
#
# **Tier 5 — System Level**
#
# **Question:** Can you build a pressing system quality metric that separates tactical design from personnel quality across Big 5 leagues?
#
# **Data:** FBref PPDA and pressing metrics + Transfermarkt squad values + StatsBomb Open Data
#
# **Why this question matters:**
# PPDA is the standard pressing metric but it conflates two things: the manager's tactical pressing system and the personnel quality available to execute it. A world-class squad pressing at moderate intensity will post better PPDA than a low-quality squad pressing with maximum effort. Building a metric that separates these contributions is one of the most practically valuable and analytically difficult problems in football metrics.
#
# **What you are building toward:**
# - A pressing system quality metric that controls for squad quality
# - Separation of tactical design contribution from personnel contribution
# - Cross-league validation of the metric
#
# ---
#
# **Critical lens (apply throughout):**
# 1. What assumptions do you need to make to separate tactical from personnel contribution — and are they defensible?
# 2. How would you validate that your metric is measuring what you claim?
# 3. What would a club use this metric for — and what are its limitations in practice?

# %% [markdown]
# ## Environment Setup

# %%
# !pip install statsbombpy mplsoccer pandas numpy matplotlib seaborn

# %%
# Import libraries

# %% [markdown]
# ## Step 1: Load multi-season pressing and squad value data
#
# Pull PPDA, pressure success rates, and pressing location data from FBref and StatsBomb across all Big 5 leagues.

# %% [markdown]
# ## Step 2: Build baseline pressing expectation model
#
# Predict expected PPDA from squad value alone. The residual is your first-pass tactical pressing quality estimate.

# %% [markdown]
# ## Step 3: Add pressing behavior features
#
# Augment with: pressing height, pressing triggers frequency, counterpress rate. Build a richer expectation model.

# %% [markdown]
# ## Step 4: Validate: manager changes at same club
#
# When a manager changes at a club with similar squad value, does your metric change as expected?

# %% [markdown]
# ## Step 5: Cross-league calibration
#
# Does the metric need league-specific calibration? Test whether coefficients hold across leagues.

# %% [markdown]
# ## Step 6: Publish a ranked list
#
# Which managers run the highest-quality pressing systems relative to their squad quality?

# %% [markdown]
# ## Interpretation and Critique

# %% [markdown]
# **1. Which managers run the highest-quality pressing systems relative to their personnel — and does the list match your prior expectations?**
#
# *(Write your answer here)*

# %% [markdown]
# **2. Describe one concrete validation test you ran and what it told you about your metric's validity.**
#
# *(Write your answer here)*

# %% [markdown]
# **3. What is the strongest criticism a peer reviewer would make of your separation approach?**
#
# *(Write your answer here)*

# %% [markdown]
# **4. How would a club use this metric in a managerial appointment decision?**
#
# *(Write your answer here)*

# %% [markdown]
# ---
#
# ## Before You Move On
#
# 1. Does your analysis pass the smell test — do the results make intuitive football sense?
# 2. What is the single biggest limitation of your methodology?
# 3. What new question did this analysis raise that it cannot answer?
#
# Add new questions to `CANDIDATE_PROBLEMS.md` before moving on.

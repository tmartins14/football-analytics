# %% [markdown]
# # Question 11: Consistent xG Overperformers Across Seasons
#
# **Tier 2 — Recruitment and Player Valuation**
#
# **Question:** Which forwards have the largest gap between non-penalty xG and actual goals — consistently across three or more seasons?
#
# **Data:** FBref + Understat — multi-season
#
# **Why this question matters:**
# Single-season xG overperformance is mostly noise. A forward who beats their xG by 3 goals in one season is probably lucky. A forward who beats it consistently across three or more seasons is probably a better finisher than the model assumes. Finding these players — and understanding why the model undervalues them — is one of the most practically useful questions in recruitment analytics.
#
# **What you are building toward:**
# - Multi-season finishing performance above expectation
# - Statistical test for whether overperformance is persistent vs random
# - Identification of shot characteristics that explain persistent overperformers
#
# ---
#
# **Critical lens (apply throughout):**
# 1. How many seasons of overperformance do you need before concluding it is a real skill rather than variance?
# 2. What shot characteristics might cause a specific player to systematically beat a population-level xG model?
# 3. Is consistent xG overperformance more likely to reflect finishing skill or systematic model mis-specification for certain shot types?

# %% [markdown]
# ## Environment Setup

# %%
# !pip install statsbombpy mplsoccer pandas numpy matplotlib seaborn

# %%
# Import libraries

# %% [markdown]
# ## Step 1: Load multi-season shot data
#
# Pull non-penalty xG and goals for forwards across at least 5 seasons from FBref and Understat. Handle players who changed teams.

# %% [markdown]
# ## Step 2: Calculate season-level overperformance
#
# Goals minus non-penalty xG per season per player. Normalise to per 90 to control for playing time.

# %% [markdown]
# ## Step 3: Filter to multi-season players
#
# Keep only players with data across 3 or more seasons with sufficient minutes. Apply a minimum shots threshold per season.

# %% [markdown]
# ## Step 4: Identify persistent overperformers
#
# Calculate average overperformance across seasons and variance. Players with consistently positive overperformance and low variance are your targets.

# %% [markdown]
# ## Step 5: Statistical significance test
#
# Use a simple t-test or bootstrap to assess whether each player's overperformance is statistically distinguishable from zero.

# %% [markdown]
# ## Step 6: Visualise consistency
#
# For top overperformers: line chart of season-by-season overperformance. Does it hold across teams and leagues?

# %% [markdown]
# ## Interpretation and Critique

# %% [markdown]
# **1. Which forwards consistently outperform their xG — and what do their shot profiles have in common?**
#
# *(Write your answer here)*

# %% [markdown]
# **2. How many seasons of overperformance would you require before recommending a player as a genuine elite finisher?**
#
# *(Write your answer here)*

# %% [markdown]
# **3. A forward overperforms xG by 4 goals in one season. How much of that should you expect to repeat next season?**
#
# *(Write your answer here)*

# %% [markdown]
# **4. What shot characteristics are most likely to cause a player to consistently beat a standard xG model?**
#
# *(Write your answer here)*

# %% [markdown]
# ---
#
# ## Before You Move On
#
# 1. Does your analysis pass the smell test — do the results make intuitive football sense?
# 2. What is the single biggest limitation of your methodology?
# 3. What new question did this analysis raise that it cannot answer?
#
# Add new questions to `CANDIDATE_PROBLEMS.md` before moving on.

# %% [markdown]
# # Question 9: Progressive Pass Volume Relative to Team Possession Share
#
# **Tier 2 — Recruitment and Player Valuation**
#
# **Question:** Which midfielders in the Big 5 leagues produce the highest progressive pass volume relative to their team's possession share?
#
# **Data:** FBref — Big 5 leagues 2017-2024
#
# **Why this question matters:**
# Raw progressive pass counts favor players on dominant possession teams. A midfielder completing 8 progressive passes per 90 on a team with 65% possession is doing less work relative to opportunity than one completing 6 on a team with 42% possession. Normalising for possession share reveals who is genuinely driving ball progression versus who benefits from system volume.
#
# **What you are building toward:**
# - A possession-adjusted progressive passing metric
# - Cross-league comparison of midfield ball progressors
# - Identification of undervalued progressors on lower-possession teams
#
# ---
#
# **Critical lens (apply throughout):**
# 1. What does FBref define as a progressive pass — and what does that definition exclude?
# 2. Does normalising for possession share fully solve the system dependency problem?
# 3. What other factors besides possession share affect a midfielder's opportunity to progress the ball?

# %% [markdown]
# ## Environment Setup

# %%
# !pip install statsbombpy mplsoccer pandas numpy matplotlib seaborn

# %%
# Import libraries

# %% [markdown]
# ## Step 1: Load FBref data
#
# Use the FBref scraping library or direct download to pull midfielder stats for Big 5 leagues from 2017-18 onward. Identify progressive pass columns.

# %% [markdown]
# ## Step 2: Load team possession share
#
# Pull team-level possession statistics for the same seasons. Join to player data by team and season.

# %% [markdown]
# ## Step 3: Calculate possession-adjusted progressive passes
#
# Progressive passes per 90 divided by team possession share. Build a percentile rank.

# %% [markdown]
# ## Step 4: Compare raw vs adjusted rankings
#
# For the top 50 progressors by raw count, how many drop significantly in the adjusted ranking? Who rises?

# %% [markdown]
# ## Step 5: Cross-league comparison
#
# Do certain leagues produce more progressors after adjustment? What does that tell you about league tactical styles?

# %% [markdown]
# ## Step 6: Multi-season consistency
#
# Which players appear in the top quartile of adjusted progressive passing across three or more seasons? Consistency is a recruitment signal.

# %% [markdown]
# ## Interpretation and Critique

# %% [markdown]
# **1. Who are the most efficient ball progressors in the Big 5 when you control for possession opportunity?**
#
# *(Write your answer here)*

# %% [markdown]
# **2. A player drops from 10th to 45th in the adjusted ranking. What does that tell you about their value?**
#
# *(Write your answer here)*

# %% [markdown]
# **3. What other system-dependency adjustments would you want to make beyond possession share?**
#
# *(Write your answer here)*

# %% [markdown]
# **4. How would you present this metric to a sporting director who only knows raw stats?**
#
# *(Write your answer here)*

# %% [markdown]
# ---
#
# ## Before You Move On
#
# 1. Does your analysis pass the smell test — do the results make intuitive football sense?
# 2. What is the single biggest limitation of your methodology?
# 3. What new question did this analysis raise that it cannot answer?
#
# Add new questions to `CANDIDATE_PROBLEMS.md` before moving on.

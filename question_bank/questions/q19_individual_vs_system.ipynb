# %% [markdown]
# # Question 19: Individual vs System — Player Transfers as Natural Experiments
#
# **Tier 4 — Causal and Econometric**
#
# **Question:** How much of a player's possession value metrics are attributable to the individual versus the system — using player transfers as natural experiments?
#
# **Data:** FBref player stats 2017-2024 + Transfermarkt transfer records
#
# **Why this question matters:**
# The system vs individual attribution problem is the most important unsolved question in football recruitment analytics. When a player moves clubs and their metrics change, how much is the player and how much is the system? Transfers provide a natural experiment: the player's individual quality is held constant while the system changes. Exploiting this structure is one of the most sophisticated things an analyst can do with publicly available data.
#
# **What you are building toward:**
# - A transfer-based natural experiment framework
# - Before/after metric comparison with system context controls
# - Estimates of individual vs system contribution to key metrics
#
# ---
#
# **Critical lens (apply throughout):**
# 1. What assumptions does the natural experiment approach require — and when are they violated?
# 2. What confounders affect player performance post-transfer beyond the system change?
# 3. How does the age of the player at transfer affect the validity of the comparison?

# %% [markdown]
# ## Environment Setup

# %%
# !pip install statsbombpy mplsoccer pandas numpy matplotlib seaborn

# %%
# Import libraries

# %% [markdown]
# ## Step 1: Build transfer dataset
#
# Use Transfermarkt to identify a large sample of transfers between teams with meaningfully different tactical contexts.

# %% [markdown]
# ## Step 2: Classify system differences
#
# Use possession share, PPDA, and progressive pass volume to characterise each team's system. Calculate system delta for each transfer.

# %% [markdown]
# ## Step 3: Load pre and post-transfer metrics
#
# Pull key possession value metrics from FBref for the season before and after each transfer.

# %% [markdown]
# ## Step 4: Difference-in-differences framework
#
# For each player: metric change = (post - pre). Regress metric change on system delta. The coefficient estimates system sensitivity.

# %% [markdown]
# ## Step 5: Identify system-robust vs system-sensitive metrics
#
# Which metrics change most with system context? Which hold stable?

# %% [markdown]
# ## Step 6: Individual quality residual
#
# The residual from your regression is the system-adjusted individual contribution. Who has the largest positive residual?

# %% [markdown]
# ## Interpretation and Critique

# %% [markdown]
# **1. Which metrics are most sensitive to system context — and which are most likely to reflect individual quality?**
#
# *(Write your answer here)*

# %% [markdown]
# **2. Explain the difference-in-differences approach to a sporting director who has no statistical background.**
#
# *(Write your answer here)*

# %% [markdown]
# **3. What are the key assumptions of your natural experiment — and give one concrete example of when each assumption might fail?**
#
# *(Write your answer here)*

# %% [markdown]
# **4. How would you use this framework to adjust your evaluation of a player you are scouting from a very different system?**
#
# *(Write your answer here)*

# %% [markdown]
# ---
#
# ## Before You Move On
#
# 1. Does your analysis pass the smell test — do the results make intuitive football sense?
# 2. What is the single biggest limitation of your methodology?
# 3. What new question did this analysis raise that it cannot answer?
#
# Add new questions to `CANDIDATE_PROBLEMS.md` before moving on.

# %% [markdown]
# # Question 8: Pass Completion Rate Under Pressure vs Not Under Pressure
#
# **Tier 2 — Recruitment and Player Valuation**
#
# **Question:** How much does a player's pass completion rate change under pressure versus not under pressure, and which players maintain quality best?
#
# **Data:** StatsBomb Open Data — pass pressure flags
#
# **Why this question matters:**
# Pass completion rate is one of the most cited recruitment metrics — and one of the most misleading. A player completing 92% of passes in a low-risk role is not more valuable than one completing 84% while consistently attempting difficult passes under pressure. This question builds a pressure-adjusted pass quality metric that separates ambition from accuracy.
#
# **What you are building toward:**
# - A pressure-adjusted pass completion metric
# - Comparison of players who maintain completion rate under pressure vs those who don't
# - Identification of players whose raw completion rate understates their true difficulty
#
# ---
#
# **Critical lens (apply throughout):**
# 1. Pass completion rate rewards conservative passing — what does that mean for how you use it in recruitment?
# 2. A player with 70% completion under pressure might be more valuable than one with 90%. When is that true?
# 3. How does pass difficulty interact with pressure — are hard passes more or less likely to be attempted under pressure?

# %% [markdown]
# ## Environment Setup

# %%
# !pip install statsbombpy mplsoccer pandas numpy matplotlib seaborn

# %%
# Import libraries

# %% [markdown]
# ## Step 1: Load pass event data
#
# Load pass events across multiple competitions. Identify the under_pressure flag and pass outcome columns.

# %% [markdown]
# ## Step 2: Classify passes by pressure and difficulty
#
# Separate passes into pressured and unpressured. Build a pass difficulty proxy using distance and angle.

# %% [markdown]
# ## Step 3: Calculate player metrics
#
# For each player: completion rate pressured, completion rate unpressured, delta between the two, and a pressure resilience score.

# %% [markdown]
# ## Step 4: Rank players by pressure resilience
#
# Apply minimum pass thresholds. Rank by smallest drop in completion rate under pressure. What positions dominate the top of the list?

# %% [markdown]
# ## Step 5: Visualise completion rate distributions
#
# Box plots comparing pressured vs unpressured completion rates by position group.

# %% [markdown]
# ## Step 6: Scatter: unpressured completion vs pressure delta
#
# X: unpressured completion rate. Y: drop under pressure. Identify players who are both accurate and resilient.

# %% [markdown]
# ## Interpretation and Critique

# %% [markdown]
# **1. Who maintains pass quality best under pressure — and what does their playing style have in common?**
#
# *(Write your answer here)*

# %% [markdown]
# **2. A scout argues that pass completion rate is the best single proxy for technical quality. Build the strongest counterargument using your findings.**
#
# *(Write your answer here)*

# %% [markdown]
# **3. How would you adjust pass completion rate to make it a fairer cross-player comparison?**
#
# *(Write your answer here)*

# %% [markdown]
# **4. What would you need to add to this metric to make it useful for comparing players across different leagues?**
#
# *(Write your answer here)*

# %% [markdown]
# ---
#
# ## Before You Move On
#
# 1. Does your analysis pass the smell test — do the results make intuitive football sense?
# 2. What is the single biggest limitation of your methodology?
# 3. What new question did this analysis raise that it cannot answer?
#
# Add new questions to `CANDIDATE_PROBLEMS.md` before moving on.

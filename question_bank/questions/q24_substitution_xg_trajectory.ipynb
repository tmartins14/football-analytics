# %% [markdown]
# # Question 24: Substitution Patterns and Second-Half xG Trajectory
#
# **Tier 5 — System Level**
#
# **Question:** How does team xG performance in the first versus second half correlate with substitution patterns — and do teams that substitute earlier outperform their first-half xG trajectory?
#
# **Data:** StatsBomb Open Data — shot and substitution events with minute stamps
#
# **Why this question matters:**
# The substitution question from Tier 4 asked whether managers are late. This question asks a harder follow-on: even if they substitute at the right time, do the substitutions actually change xG trajectory? Separating the effect of timing from the effect of personnel quality is a multi-stage analytical problem that requires sustained attention to measurement across an entire dataset.
#
# **What you are building toward:**
# - xG trajectory by 15-minute match window per team
# - Substitution timing and personnel data joined to xG windows
# - Causal estimate of substitution effect on post-substitution xG
#
# ---
#
# **Critical lens (apply throughout):**
# 1. How do you define xG trajectory — per window absolute or relative to first-half baseline?
# 2. What confounds the relationship between substitution timing and post-substitution xG?
# 3. How do you handle the game state at the time of substitution — a losing team substituting earlier is not comparable to a winning team?

# %% [markdown]
# ## Environment Setup

# %%
# !pip install statsbombpy mplsoccer pandas numpy matplotlib seaborn

# %%
# Import libraries

# %% [markdown]
# ## Step 1: Build match-level xG time series
#
# For each match, calculate xG generated in each 15-minute window. Build a per-team average across the season.

# %% [markdown]
# ## Step 2: Identify first to second half xG changes
#
# Which teams show the largest positive and negative xG shifts from first to second half?

# %% [markdown]
# ## Step 3: Join substitution data
#
# Add: time of first substitution, number of substitutions by 60 minutes, whether substitutions were tactical or injury-forced.

# %% [markdown]
# ## Step 4: Stratify by game state
#
# Separate analysis for teams winning, drawing, and losing at half time. Does the substitution effect differ by game state?

# %% [markdown]
# ## Step 5: Regression: early substitution on second half xG
#
# Control for first half xG and game state. Estimate the marginal effect of substituting before the 60th minute.

# %% [markdown]
# ## Step 6: Visualise xG trajectories
#
# For teams grouped by substitution timing strategy: line charts of average xG per 15-minute window.

# %% [markdown]
# ## Interpretation and Critique

# %% [markdown]
# **1. Do teams that substitute earlier show better second-half xG trajectories — after controlling for game state?**
#
# *(Write your answer here)*

# %% [markdown]
# **2. What is the most important confounder in this analysis — and how did you handle it?**
#
# *(Write your answer here)*

# %% [markdown]
# **3. What does this analysis tell you about the value of a deep squad versus relying on a starting eleven?**
#
# *(Write your answer here)*

# %% [markdown]
# **4. How would you present these findings to a manager who resists early substitutions?**
#
# *(Write your answer here)*

# %% [markdown]
# ---
#
# ## Before You Move On
#
# 1. Does your analysis pass the smell test — do the results make intuitive football sense?
# 2. What is the single biggest limitation of your methodology?
# 3. What new question did this analysis raise that it cannot answer?
#
# Add new questions to `CANDIDATE_PROBLEMS.md` before moving on.

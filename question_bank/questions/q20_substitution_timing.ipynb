# %% [markdown]
# # Question 20: Are Managers Systematically Late With Substitutions?
#
# **Tier 4 — Causal and Econometric**
#
# **Question:** Are managers systematically late with substitutions relative to optimal timing — and can injury-forced substitutions serve as an instrument to test this?
#
# **Data:** StatsBomb Open Data — substitution and injury events + FBref match outcomes
#
# **Why this question matters:**
# Substitution timing is one of the few manager decisions that can be measured precisely from data. If managers are systematically late — waiting until the 70th minute when early substitutions would produce better outcomes — that is an exploitable inefficiency. Using injury-forced substitutions as an instrumental variable is a sophisticated identification strategy that introduces econometric thinking to a practical football question.
#
# **What you are building toward:**
# - A substitution timing dataset with match context
# - Comparison of outcomes by substitution timing
# - An instrumental variable approach using injury-forced substitutions
#
# ---
#
# **Critical lens (apply throughout):**
# 1. What is an instrumental variable — and why might injury-forced substitutions serve as one here?
# 2. What assumptions does the IV approach require — and are they plausible?
# 3. How do you measure whether a substitution improved outcomes — what is the right outcome variable?

# %% [markdown]
# ## Environment Setup

# %%
# !pip install statsbombpy mplsoccer pandas numpy matplotlib seaborn

# %%
# Import libraries

# %% [markdown]
# ## Step 1: Load substitution events
#
# From StatsBomb, extract all substitution events with minute, match context, and whether substitution was injury-forced.

# %% [markdown]
# ## Step 2: Load match outcome data
#
# Join substitutions to match outcomes. Build a dataset of: substitution minute, game state at substitution, subsequent goals, and final outcome.

# %% [markdown]
# ## Step 3: Naive analysis: timing vs outcomes
#
# Does earlier substitution correlate with better post-substitution outcomes? Plot the naive relationship.

# %% [markdown]
# ## Step 4: Identify injury-forced substitutions
#
# Flag substitutions that appear injury-forced based on StatsBomb injury event flags. This is your instrument.

# %% [markdown]
# ## Step 5: First stage: does injury force earlier substitution?
#
# Regress substitution minute on injury flag. Injury-forced substitutions should happen earlier on average.

# %% [markdown]
# ## Step 6: Second stage: effect of early substitution on outcomes
#
# Using injury as an instrument, estimate the causal effect of earlier substitution timing on subsequent team performance.

# %% [markdown]
# ## Interpretation and Critique

# %% [markdown]
# **1. Are managers systematically late with substitutions in your data — and how large is the effect?**
#
# *(Write your answer here)*

# %% [markdown]
# **2. Explain why injury-forced substitutions might be a valid instrument — and identify one reason they might not be.**
#
# *(Write your answer here)*

# %% [markdown]
# **3. What is the local average treatment effect (LATE) estimated by your IV approach — and what does it mean practically?**
#
# *(Write your answer here)*

# %% [markdown]
# **4. If managers are late with substitutions, what behavioral explanation best accounts for it?**
#
# *(Write your answer here)*

# %% [markdown]
# ---
#
# ## Before You Move On
#
# 1. Does your analysis pass the smell test — do the results make intuitive football sense?
# 2. What is the single biggest limitation of your methodology?
# 3. What new question did this analysis raise that it cannot answer?
#
# Add new questions to `CANDIDATE_PROBLEMS.md` before moving on.

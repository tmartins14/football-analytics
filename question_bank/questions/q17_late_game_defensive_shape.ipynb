# %% [markdown]
# # Question 17: Defensive Shape Adaptation When Protecting a One-Goal Lead
#
# **Tier 3 — Tactical and Opposition Analysis**
#
# **Question:** How do managers adapt their team's defensive shape in the final 15 minutes when protecting a one-goal lead?
#
# **Data:** StatsBomb Open Data — event sequences with minute and game state
#
# **Why this question matters:**
# The final 15 minutes of a one-goal game is one of the highest-leverage tactical situations in football. Managers must decide whether to maintain their structure, drop deeper, make defensive substitutions, or time-waste. Measuring whether these adaptations actually change defensive outcomes — and which adaptations work best — is a question coaching staffs genuinely debate.
#
# **What you are building toward:**
# - A late-game defensive adaptation taxonomy
# - Measurement of defensive shape changes after the 75th minute when winning by one
# - Comparison of outcomes by adaptation type
#
# ---
#
# **Critical lens (apply throughout):**
# 1. How do you measure defensive shape change from event data alone — without tracking data?
# 2. Is a team dropping deeper in the final 15 minutes making a tactical choice or being pushed back?
# 3. What outcome measure best captures whether the adaptation succeeded?

# %% [markdown]
# ## Environment Setup

# %%
# !pip install statsbombpy mplsoccer pandas numpy matplotlib seaborn

# %%
# Import libraries

# %% [markdown]
# ## Step 1: Identify one-goal lead situations in final 15 minutes
#
# Filter matches to those where a team leads by exactly one goal after the 75th minute.

# %% [markdown]
# ## Step 2: Measure defensive compactness proxies
#
# Use defensive action locations as a proxy for defensive line height. Compare 60-75 minute window to 75-90 minute window.

# %% [markdown]
# ## Step 3: Identify substitution patterns
#
# Do managers make defensive substitutions in this situation? How often and when?

# %% [markdown]
# ## Step 4: Measure pressing intensity change
#
# Does PPDA increase or decrease in the final 15 when protecting a lead?

# %% [markdown]
# ## Step 5: Outcomes analysis
#
# For teams in this situation: what proportion held the lead, conceded an equaliser, or conceded to lose?

# %% [markdown]
# ## Step 6: Compare adaptation strategies
#
# Do teams that drop deeper hold leads more successfully than those that maintain shape?

# %% [markdown]
# ## Interpretation and Critique

# %% [markdown]
# **1. What is the most common tactical adaptation when protecting a one-goal lead in the final 15 — and does it work?**
#
# *(Write your answer here)*

# %% [markdown]
# **2. How do you separate tactical intent from being pushed back when a team's defensive line drops in the final 15?**
#
# *(Write your answer here)*

# %% [markdown]
# **3. A manager asks you whether to press or sit deep when protecting a late lead against a specific opponent. What data would you pull?**
#
# *(Write your answer here)*

# %% [markdown]
# **4. What are the limitations of using event data to measure defensive shape — and what would tracking data add?**
#
# *(Write your answer here)*

# %% [markdown]
# ---
#
# ## Before You Move On
#
# 1. Does your analysis pass the smell test — do the results make intuitive football sense?
# 2. What is the single biggest limitation of your methodology?
# 3. What new question did this analysis raise that it cannot answer?
#
# Add new questions to `CANDIDATE_PROBLEMS.md` before moving on.

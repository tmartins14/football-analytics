# %% [markdown]
# # Question 14: xG Conceded from Transitions vs Pressing Intensity
#
# **Tier 3 — Tactical and Opposition Analysis**
#
# **Question:** Which teams concede the most xG from transitions specifically, and how does that correlate with their pressing intensity in possession?
#
# **Data:** StatsBomb Open Data — carry and shot events with play pattern flags
#
# **Why this question matters:**
# High pressing teams expose themselves to transitions. When the press is broken, the defense is disorganised and the space behind it is vast. Quantifying transition vulnerability — not just goals conceded but xG quality of transition chances — reveals a specific tactical trade-off that standard defensive metrics obscure.
#
# **What you are building toward:**
# - A transition event classification from StatsBomb play pattern data
# - xG conceded from transitions vs set shape defensive situations
# - Correlation between pressing intensity and transition vulnerability
#
# ---
#
# **Critical lens (apply throughout):**
# 1. How does StatsBomb flag transition situations — and what does that definition miss?
# 2. Is transition vulnerability a feature or a bug of high-press systems — and how do you tell?
# 3. What confounders make the pressing-transition relationship hard to interpret causally?

# %% [markdown]
# ## Environment Setup

# %%
# !pip install statsbombpy mplsoccer pandas numpy matplotlib seaborn

# %%
# Import libraries

# %% [markdown]
# ## Step 1: Classify shots by game situation
#
# Use StatsBomb play pattern flags to separate shots from open play, transitions, set pieces, and other situations.

# %% [markdown]
# ## Step 2: Calculate transition xG conceded per team
#
# For each team: total xG conceded from transitions per 90. Separate home and away.

# %% [markdown]
# ## Step 3: Calculate pressing intensity per team
#
# Use PPDA approximation from event data or pressure event counts per defensive action.

# %% [markdown]
# ## Step 4: Scatter: pressing intensity vs transition xG conceded
#
# Is there a relationship? Is it linear?

# %% [markdown]
# ## Step 5: Identify outliers
#
# Which teams press heavily but concede little from transitions — what explains their resilience?

# %% [markdown]
# ## Step 6: Time-series: when in the match do transitions occur most?
#
# Split transition xG conceded by 15-minute match window.

# %% [markdown]
# ## Interpretation and Critique

# %% [markdown]
# **1. Is there a meaningful relationship between pressing intensity and transition vulnerability in your data?**
#
# *(Write your answer here)*

# %% [markdown]
# **2. Name a team that presses heavily but has low transition xG conceded. What tactical mechanisms might explain that?**
#
# *(Write your answer here)*

# %% [markdown]
# **3. An opposition analyst wants to identify the best moments to play through a high-press team. What does your analysis tell them?**
#
# *(Write your answer here)*

# %% [markdown]
# **4. What does transition xG conceded tell you that goals conceded from transitions does not?**
#
# *(Write your answer here)*

# %% [markdown]
# ---
#
# ## Before You Move On
#
# 1. Does your analysis pass the smell test — do the results make intuitive football sense?
# 2. What is the single biggest limitation of your methodology?
# 3. What new question did this analysis raise that it cannot answer?
#
# Add new questions to `CANDIDATE_PROBLEMS.md` before moving on.

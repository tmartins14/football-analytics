# %% [markdown]
# # Question 16: Defensive Systems and Central Zone Shot Suppression
#
# **Tier 3 — Tactical and Opposition Analysis**
#
# **Question:** Which defensive systems allow the fewest shots from central zones, and how does their pressure positioning differ from high-conceding teams?
#
# **Data:** StatsBomb Open Data — shot location and pressure events
#
# **Why this question matters:**
# Not all shots are equal and not all defensive systems are equal at preventing dangerous shots specifically. A team might concede few shots overall but allow a high proportion from central zones — where xG is highest. Understanding which defensive systems most effectively suppress central zone shots, and what pressing behavior underpins that, has direct coaching and recruitment implications.
#
# **What you are building toward:**
# - Shot location analysis by zone with defensive context
# - Comparison of pressure positioning between low and high central-shot-conceding teams
# - A central shot suppression metric
#
# ---
#
# **Critical lens (apply throughout):**
# 1. How do you define the central zone — and does your definition affect the results?
# 2. Is central shot suppression a defensive shape outcome or a pressing outcome — or both?
# 3. What confounders explain central shot differences beyond defensive system quality?

# %% [markdown]
# ## Environment Setup

# %%
# !pip install statsbombpy mplsoccer pandas numpy matplotlib seaborn

# %%
# Import libraries

# %% [markdown]
# ## Step 1: Define central zone
#
# Document your zone definition. Consider using the StatsBomb pitch coordinate system to define a central danger zone.

# %% [markdown]
# ## Step 2: Calculate central shot conceded metrics
#
# For each team: shots conceded from central zone per 90, xG conceded from central zone per 90, proportion of shots conceded that are central.

# %% [markdown]
# ## Step 3: Load pressure positioning data
#
# Where are defensive pressures applied for high vs low central-shot-conceding teams?

# %% [markdown]
# ## Step 4: Build pressure positioning heatmaps
#
# Using mplsoccer: plot average pressure locations for the top 5 and bottom 5 teams by central shot suppression.

# %% [markdown]
# ## Step 5: Statistical comparison
#
# Do low-conceding teams pressure significantly differently in specific zones?

# %% [markdown]
# ## Step 6: Team profiles
#
# Build a summary table: central shot suppression ranking with key pressure metrics alongside.

# %% [markdown]
# ## Interpretation and Critique

# %% [markdown]
# **1. Which defensive systems are most effective at suppressing central zone shots — and what pressure behavior characterises them?**
#
# *(Write your answer here)*

# %% [markdown]
# **2. Is central shot suppression primarily a function of defensive shape or pressing intensity?**
#
# *(Write your answer here)*

# %% [markdown]
# **3. How would an opposition analyst use this analysis to prepare a game plan against a central-shot-suppressing team?**
#
# *(Write your answer here)*

# %% [markdown]
# **4. What does this analysis tell you about the trade-offs of different defensive systems?**
#
# *(Write your answer here)*

# %% [markdown]
# ---
#
# ## Before You Move On
#
# 1. Does your analysis pass the smell test — do the results make intuitive football sense?
# 2. What is the single biggest limitation of your methodology?
# 3. What new question did this analysis raise that it cannot answer?
#
# Add new questions to `CANDIDATE_PROBLEMS.md` before moving on.

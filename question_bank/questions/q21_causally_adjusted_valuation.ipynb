# %% [markdown]
# # Question 21: Causally-Adjusted Player Valuation vs Transfer Fees
#
# **Tier 4 — Causal and Econometric**
#
# **Question:** Does a causally-adjusted player valuation model predict transfer fees better than raw output metrics — and where does the market systematically misprice players?
#
# **Data:** FBref + Transfermarkt transfer fees + Understat xG
#
# **Why this question matters:**
# Transfer fee prediction is the applied test of whether your analytical framework captures real value. If a model that controls for system dependency, age curves, and positional context predicts fees better than raw output metrics, it demonstrates that the market rewards the underlying quality the model measures. Where the model and market diverge most is where analytical edge exists.
#
# **What you are building toward:**
# - A multi-variable transfer fee prediction model
# - Comparison of raw vs causally-adjusted model performance
# - Identification of systematically mispriced players
#
# ---
#
# **Critical lens (apply throughout):**
# 1. What does transfer fee reflect beyond player quality — and how does that affect your model?
# 2. What is the difference between explaining variance in fees and predicting future fees?
# 3. Where are transfer markets most and least efficient — and why?

# %% [markdown]
# ## Environment Setup

# %%
# !pip install statsbombpy mplsoccer pandas numpy matplotlib seaborn

# %%
# Import libraries

# %% [markdown]
# ## Step 1: Build transfer fee dataset
#
# Pull transfer fees from Transfermarkt for a large sample of transfers. Clean and normalise for inflation and league purchasing power.

# %% [markdown]
# ## Step 2: Build raw metrics model
#
# Predict transfer fee from raw output metrics (xG, xA, progressive passes per 90). Assess R-squared and RMSE.

# %% [markdown]
# ## Step 3: Build adjusted metrics model
#
# Add system-context adjustments from Question 19 methodology. Age curve adjustment. Positional context. Reassess model performance.

# %% [markdown]
# ## Step 4: Compare model performance
#
# Does adjustment improve prediction? On which player types does it help most?

# %% [markdown]
# ## Step 5: Identify mispriced players
#
# Players where the model significantly over or underpredicts the actual fee. What do they have in common?

# %% [markdown]
# ## Step 6: Market efficiency by league
#
# Does the model predict fees better for some leagues than others? Which leagues appear least efficient?

# %% [markdown]
# ## Interpretation and Critique

# %% [markdown]
# **1. Does your causally-adjusted model outperform the raw metrics model — and where does the improvement come from?**
#
# *(Write your answer here)*

# %% [markdown]
# **2. Name three players your model identifies as significantly mispriced. Do those findings make intuitive sense?**
#
# *(Write your answer here)*

# %% [markdown]
# **3. What non-analytical factors drive transfer fees that your model cannot capture?**
#
# *(Write your answer here)*

# %% [markdown]
# **4. Where in the market would you focus analytical resource if you were a club trying to find value?**
#
# *(Write your answer here)*

# %% [markdown]
# ---
#
# ## Before You Move On
#
# 1. Does your analysis pass the smell test — do the results make intuitive football sense?
# 2. What is the single biggest limitation of your methodology?
# 3. What new question did this analysis raise that it cannot answer?
#
# Add new questions to `CANDIDATE_PROBLEMS.md` before moving on.

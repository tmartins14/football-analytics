# %% [markdown]
# # Question 12: Defensive Contribution When Possession Share Drops
#
# **Tier 2 — Recruitment and Player Valuation**
#
# **Question:** How does a player's defensive contribution as measured by pressures and tackles change when their team's possession share drops significantly?
#
# **Data:** FBref — player defensive stats across seasons
#
# **Why this question matters:**
# Defensive metrics are even more system-dependent than attacking ones. A midfielder on a 60% possession team presses far less often than one on a 38% possession team — not because they are a worse presser, but because they have fewer opportunities. Understanding how defensive metrics scale with possession context is essential for cross-team player comparison.
#
# **What you are building toward:**
# - Possession-adjusted defensive metrics
# - Comparison of how defensive output changes when the same player moves to a different possession context
# - Identification of metrics most and least sensitive to possession share
#
# ---
#
# **Critical lens (apply throughout):**
# 1. Which defensive metrics are most sensitive to team possession share — and which are most robust?
# 2. A player's tackles per 90 doubles after moving to a lower possession team. Is that a good sign or a bad sign?
# 3. How do you separate a player's defensive quality from their defensive opportunity?

# %% [markdown]
# ## Environment Setup

# %%
# !pip install statsbombpy mplsoccer pandas numpy matplotlib seaborn

# %%
# Import libraries

# %% [markdown]
# ## Step 1: Load player defensive stats across seasons
#
# Pull pressures, tackles, interceptions, and defensive actions per 90 from FBref across multiple seasons for a large player sample.

# %% [markdown]
# ## Step 2: Load team possession data
#
# Join to team-level possession share by player, team, and season.

# %% [markdown]
# ## Step 3: Correlate defensive metrics with possession share
#
# For each defensive metric: how strongly does it correlate with team possession share at the player level?

# %% [markdown]
# ## Step 4: Identify players with large possession context shifts
#
# Find players who experienced a large shift in team possession share across seasons. Compare their defensive metrics before and after.

# %% [markdown]
# ## Step 5: Build possession-adjusted defensive metrics
#
# Normalise each defensive metric by opponent possession share (time the opponent has the ball). Which metrics change least?

# %% [markdown]
# ## Step 6: Rank players by adjusted defensive contribution
#
# Who rises and who falls in the adjusted rankings?

# %% [markdown]
# ## Interpretation and Critique

# %% [markdown]
# **1. Which defensive metrics are most sensitive to possession context — and which should you trust most when comparing players across teams?**
#
# *(Write your answer here)*

# %% [markdown]
# **2. A player's pressures per 90 drops by 40% after moving to a higher possession team. How do you interpret that for a scout?**
#
# *(Write your answer here)*

# %% [markdown]
# **3. Build a possession-adjusted defensive ranking. Does it change your view of any players you know well?**
#
# *(Write your answer here)*

# %% [markdown]
# **4. What defensive qualities are impossible to measure with available event data — regardless of possession adjustment?**
#
# *(Write your answer here)*

# %% [markdown]
# ---
#
# ## Before You Move On
#
# 1. Does your analysis pass the smell test — do the results make intuitive football sense?
# 2. What is the single biggest limitation of your methodology?
# 3. What new question did this analysis raise that it cannot answer?
#
# Add new questions to `CANDIDATE_PROBLEMS.md` before moving on.

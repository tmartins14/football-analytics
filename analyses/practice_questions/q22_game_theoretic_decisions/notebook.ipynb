# %% [markdown]
# # Question 22: Tactical Decision Frequency vs Game-Theoretically Optimal Frequency
#
# **Tier 4 — Causal and Econometric**
#
# **Question:** Which tactical decisions show the largest gap between observed frequency and game-theoretically optimal frequency — using opponent response patterns as evidence?
#
# **Data:** StatsBomb Open Data — multi-season event sequences across competitions
#
# **Why this question matters:**
# Game theory predicts that in equilibrium, a team should mix strategies such that the opponent is indifferent between defending each option. If a team shoots from long range 5% of the time and that produces a better outcome than passing, they should shoot more until the opponent adjusts. Finding decisions where observed frequency deviates from equilibrium reveals exploitable tactical inefficiencies.
#
# **What you are building toward:**
# - Outcome rates for key tactical decisions (shoot vs pass, cross vs cut back, press vs drop)
# - Comparison of observed frequency to outcome-maximising frequency
# - Identification of the largest gaps from equilibrium
#
# ---
#
# **Critical lens (apply throughout):**
# 1. What is a mixed strategy Nash equilibrium — and why should football decisions approach it?
# 2. What evidence would indicate a team is NOT in equilibrium on a specific decision?
# 3. What practical constraints prevent teams from reaching theoretical equilibrium?

# %% [markdown]
# ## Environment Setup

# %%
# !pip install statsbombpy mplsoccer pandas numpy matplotlib seaborn

# %%
# Import libraries

# %% [markdown]
# ## Step 1: Select tactical decisions to analyse
#
# Choose 3-5 binary decisions with clear alternatives: shoot vs pass in shooting zone, cross vs carry vs cut back from wide, press vs hold shape after losing possession.

# %% [markdown]
# ## Step 2: Calculate outcome rates by decision
#
# For each decision option: probability of shot, probability of goal, xG generated. Which option produces better outcomes?

# %% [markdown]
# ## Step 3: Calculate observed decision frequency
#
# How often do teams choose each option in the relevant situations?

# %% [markdown]
# ## Step 4: Test for equilibrium
#
# If option A produces better outcomes than option B, opponents should be defending A more. Is there evidence of opponent adjustment?

# %% [markdown]
# ## Step 5: Identify largest gaps from equilibrium
#
# Where does observed frequency diverge most from what outcomes suggest should be optimal?

# %% [markdown]
# ## Step 6: Team-level variation
#
# Do some teams exploit these gaps more than others?

# %% [markdown]
# ## Interpretation and Critique

# %% [markdown]
# **1. Which tactical decision shows the largest gap between observed and optimal frequency in your data?**
#
# *(Write your answer here)*

# %% [markdown]
# **2. Explain the mixed strategy Nash equilibrium concept using a specific example from your analysis.**
#
# *(Write your answer here)*

# %% [markdown]
# **3. A manager asks why they should mix strategies rather than always choosing the option with the best average outcome. What do you tell them?**
#
# *(Write your answer here)*

# %% [markdown]
# **4. What practical constraints prevent real football teams from reaching theoretical equilibrium?**
#
# *(Write your answer here)*

# %% [markdown]
# ---
#
# ## Before You Move On
#
# 1. Does your analysis pass the smell test — do the results make intuitive football sense?
# 2. What is the single biggest limitation of your methodology?
# 3. What new question did this analysis raise that it cannot answer?
#
# Add new questions to `OPEN_QUESTIONS.md` before moving on.

# %% [markdown]
# # Question 10: Player Metrics After Transitioning Between Team Styles
#
# **Tier 2 — Recruitment and Player Valuation**
#
# **Question:** Do players who transition from a high-possession team to a low-possession team show systematic declines in key metrics beyond what team context predicts?
#
# **Data:** FBref player stats + Transfermarkt transfer records
#
# **Why this question matters:**
# One of the most persistent questions in recruitment analytics is how much of a player's output is system-dependent. If a player's metrics decline after moving to a lower-possession team, is that a real decline in quality or a context shift? Answering this has direct implications for how clubs evaluate players from dominant teams and how they should discount inflated stats.
#
# **What you are building toward:**
# - A transfer dataset linking players to pre and post-transfer team contexts
# - Before/after metric comparison controlling for team possession share
# - Identification of metrics that are most and least system-dependent
#
# ---
#
# **Critical lens (apply throughout):**
# 1. What is the counterfactual problem here — how do you know what the player would have done if they stayed?
# 2. What metrics are most likely to be system-dependent and which are most likely to reflect individual quality?
# 3. How do you control for aging effects when comparing pre and post-transfer performance?

# %% [markdown]
# ## Environment Setup

# %%
# !pip install statsbombpy mplsoccer pandas numpy matplotlib seaborn

# %%
# Import libraries

# %% [markdown]
# ## Step 1: Build transfer dataset
#
# Use Transfermarkt to identify players who moved between teams with significantly different possession shares. Define your threshold for 'high' vs 'low' possession.

# %% [markdown]
# ## Step 2: Load pre and post-transfer FBref stats
#
# For each transferred player, load the season before and season after the transfer. Handle players who changed clubs mid-season.

# %% [markdown]
# ## Step 3: Calculate possession share delta
#
# For each transfer, calculate the change in team possession share. Classify transfers as high-to-low, low-to-high, and similar-to-similar.

# %% [markdown]
# ## Step 4: Compare metric changes by transfer type
#
# For each metric: calculate average change for high-to-low transfers vs low-to-high. Which metrics show the largest systematic shifts?

# %% [markdown]
# ## Step 5: Control for age
#
# Separate players transferring in their peak years (24-28) from those transferring older. Does the system dependency effect hold across age groups?

# %% [markdown]
# ## Step 6: Identify robust metrics
#
# Which metrics change least when a player moves between possession contexts? These are your most reliable cross-context evaluation tools.

# %% [markdown]
# ## Interpretation and Critique

# %% [markdown]
# **1. Which metrics decline most systematically when a player moves from high to low possession? What does that tell a recruiter?**
#
# *(Write your answer here)*

# %% [markdown]
# **2. Name a specific metric that appears robust to team context changes — and explain why you trust it.**
#
# *(Write your answer here)*

# %% [markdown]
# **3. A player has elite stats on a 65% possession team. How would you adjust your valuation before recommending them to a 42% possession team?**
#
# *(Write your answer here)*

# %% [markdown]
# **4. What is the fundamental identification problem in this analysis — and how does it limit your conclusions?**
#
# *(Write your answer here)*

# %% [markdown]
# ---
#
# ## Before You Move On
#
# 1. Does your analysis pass the smell test — do the results make intuitive football sense?
# 2. What is the single biggest limitation of your methodology?
# 3. What new question did this analysis raise that it cannot answer?
#
# Add new questions to `OPEN_QUESTIONS.md` before moving on.
